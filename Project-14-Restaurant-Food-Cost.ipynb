# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r'C:\Users\Hi\Desktop\Data_Train_Restaurant.xlsx')
df
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 12685        QUICK BITES          13228
# 12686  CASUAL DINING,BAR           9686
# 12687             LOUNGE          11133
# 12688      CASUAL DINING           6134
# 12689      CASUAL DINING           6430
#
#                                                CUISINES  \
# 0                           Malwani, Goan, North Indian
# 1                        Asian, Modern Indian, Japanese
# 2            North Indian, Chinese, Biryani, Hyderabadi
# 3                                      Tibetan, Chinese
# 4                                              Desserts
# ...                                                 ...
# 12685                       North Indian, Burger, Kebab
# ...

# %%
df.isna().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              112
# LOCALITY           98
# RATING              2
# VOTES            1204
# COST                0
# dtype: int64

# %%
df=df.dropna(subset = ['CITY']) 
df=df.dropna(subset = ['LOCALITY']) 
df=df.dropna(subset = ['RATING'])      # drop nan values of dataset wrt CITY, LOCALITY, RATING, VOTES
df=df.dropna(subset = ['VOTES']) 
df = df.reset_index(drop=True)
df
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 11388        QUICK BITES          13228
# 11389  CASUAL DINING,BAR           9686
# 11390             LOUNGE          11133
# 11391      CASUAL DINING           6134
# 11392      CASUAL DINING           6430
#
#                                                CUISINES  \
# 0                           Malwani, Goan, North Indian
# 1                        Asian, Modern Indian, Japanese
# 2            North Indian, Chinese, Biryani, Hyderabadi
# 3                                      Tibetan, Chinese
# 4                                              Desserts
# ...                                                 ...
# 11388                       North Indian, Burger, Kebab
# ...

# %%
df.isna().sum()
# Out:
# TITLE            0
# RESTAURANT_ID    0
# CUISINES         0
# TIME             0
# CITY             0
# LOCALITY         0
# RATING           0
# VOTES            0
# COST             0
# dtype: int64

# %%
df=df.drop(['RESTAURANT_ID'],axis=1)    # column not required for data analysis
df
# Out:
#                    TITLE                                          CUISINES  \
# 0          CASUAL DINING                       Malwani, Goan, North Indian
# 1      CASUAL DINING,BAR                    Asian, Modern Indian, Japanese
# 2          CASUAL DINING        North Indian, Chinese, Biryani, Hyderabadi
# 3            QUICK BITES                                  Tibetan, Chinese
# 4         DESSERT PARLOR                                          Desserts
# ...                  ...                                               ...
# 11388        QUICK BITES                       North Indian, Burger, Kebab
# 11389  CASUAL DINING,BAR                                 Goan, Continental
# 11390             LOUNGE          Finger Food, Continental, Asian, Chinese
# 11391      CASUAL DINING  North Indian, South Indian, Chinese, Street Food
# 11392      CASUAL DINING                             North Indian, Chinese
#
# ...

# %%
df=df.drop(['TIME'],axis=1)  # column not required, has not much relation with Target variable COST  
df
# Out:
#                    TITLE                                          CUISINES  \
# 0          CASUAL DINING                       Malwani, Goan, North Indian
# 1      CASUAL DINING,BAR                    Asian, Modern Indian, Japanese
# 2          CASUAL DINING        North Indian, Chinese, Biryani, Hyderabadi
# 3            QUICK BITES                                  Tibetan, Chinese
# 4         DESSERT PARLOR                                          Desserts
# ...                  ...                                               ...
# 11388        QUICK BITES                       North Indian, Burger, Kebab
# 11389  CASUAL DINING,BAR                                 Goan, Continental
# 11390             LOUNGE          Finger Food, Continental, Asian, Chinese
# 11391      CASUAL DINING  North Indian, South Indian, Chinese, Street Food
# 11392      CASUAL DINING                             North Indian, Chinese
#
#               CITY              LOCALITY RATING       VOTES  COST
# ...

# %%
print(df['TITLE'].unique())                  
print(df['CUISINES'].unique())                         
print(df['CITY'].unique())                  
print(df['LOCALITY'].unique())    
print(df['RATING'].unique())         
print(df['VOTES'].unique())         
print(df['COST'].unique())
# Out:
# ['CASUAL DINING' 'CASUAL DINING,BAR' 'QUICK BITES' 'DESSERT PARLOR' 'CAFÉ'
#  'MICROBREWERY' 'QUICK BITES,BEVERAGE SHOP' 'CASUAL DINING,IRANI CAFE'
#  'BAKERY,QUICK BITES' 'None' 'BAR,CASUAL DINING' 'BAR' 'PUB'
#  'BEVERAGE SHOP' 'FINE DINING' 'CAFÉ,QUICK BITES'
#  'BEVERAGE SHOP,DESSERT PARLOR' 'SWEET SHOP,QUICK BITES'
#  'DESSERT PARLOR,SWEET SHOP' 'BAKERY' 'BAKERY,DESSERT PARLOR' 'BAR,LOUNGE'
#  'FOOD COURT' 'LOUNGE' 'DESSERT PARLOR,BEVERAGE SHOP'
#  'LOUNGE,CASUAL DINING' 'QUICK BITES,FOOD COURT' 'SWEET SHOP'
#  'PUB,CASUAL DINING' 'MESS' 'MICROBREWERY,CASUAL DINING'
#  'CASUAL DINING,SWEET SHOP' 'KIOSK' 'QUICK BITES,KIOSK' 'CLUB'
#  'FINE DINING,BAR' 'DESSERT PARLOR,QUICK BITES' 'FOOD COURT,QUICK BITES'
#  'LOUNGE,CAFÉ' 'BAKERY,CONFECTIONERY' 'DHABA' 'CAFÉ,DESSERT PARLOR'
#  'CASUAL DINING,CAFÉ' 'QUICK BITES,DESSERT PARLOR' 'PUB,MICROBREWERY'
#  'LOUNGE,BAR' 'DESSERT PARLOR,CAFÉ' 'CAFÉ,BAR' 'SWEET SHOP,CONFECTIONERY'
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#                    TITLE                                          CUISINES  \
# 0          CASUAL DINING                       Malwani, Goan, North Indian
# 1      CASUAL DINING,BAR                    Asian, Modern Indian, Japanese
# 2          CASUAL DINING        North Indian, Chinese, Biryani, Hyderabadi
# 3            QUICK BITES                                  Tibetan, Chinese
# 4         DESSERT PARLOR                                          Desserts
# ...                  ...                                               ...
# 11388        QUICK BITES                       North Indian, Burger, Kebab
# 11389  CASUAL DINING,BAR                                 Goan, Continental
# 11390             LOUNGE          Finger Food, Continental, Asian, Chinese
# 11391      CASUAL DINING  North Indian, South Indian, Chinese, Street Food
# 11392      CASUAL DINING                             North Indian, Chinese
#
#               CITY              LOCALITY RATING       VOTES  COST
# ...

# %%
print(df['TITLE'].unique())                 
print(df['CUISINES'].unique())                       
print(df['CITY'].unique())                  
print(df['LOCALITY'].unique())    
print(df['RATING'].unique())         
print(df['VOTES'].unique())         
print(df['COST'].unique())
# Out:
# ['CASUAL DINING' 'CASUAL DINING,BAR' 'QUICK BITES' 'DESSERT PARLOR' 'CAFÉ'
#  'MICROBREWERY' 'QUICK BITES,BEVERAGE SHOP' 'CASUAL DINING,IRANI CAFE'
#  'BAKERY,QUICK BITES' 'None' 'BAR,CASUAL DINING' 'BAR' 'PUB'
#  'BEVERAGE SHOP' 'FINE DINING' 'CAFÉ,QUICK BITES'
#  'BEVERAGE SHOP,DESSERT PARLOR' 'SWEET SHOP,QUICK BITES'
#  'DESSERT PARLOR,SWEET SHOP' 'BAKERY' 'BAKERY,DESSERT PARLOR' 'BAR,LOUNGE'
#  'FOOD COURT' 'LOUNGE' 'DESSERT PARLOR,BEVERAGE SHOP'
#  'LOUNGE,CASUAL DINING' 'QUICK BITES,FOOD COURT' 'SWEET SHOP'
#  'PUB,CASUAL DINING' 'MESS' 'MICROBREWERY,CASUAL DINING'
#  'CASUAL DINING,SWEET SHOP' 'KIOSK' 'QUICK BITES,KIOSK' 'CLUB'
#  'FINE DINING,BAR' 'DESSERT PARLOR,QUICK BITES' 'FOOD COURT,QUICK BITES'
#  'LOUNGE,CAFÉ' 'BAKERY,CONFECTIONERY' 'DHABA' 'CAFÉ,DESSERT PARLOR'
#  'CASUAL DINING,CAFÉ' 'QUICK BITES,DESSERT PARLOR' 'PUB,MICROBREWERY'
#  'LOUNGE,BAR' 'DESSERT PARLOR,CAFÉ' 'CAFÉ,BAR' 'SWEET SHOP,CONFECTIONERY'
# ...

# %%
df = df.reset_index(drop=True)
df
# Out:
#                    TITLE                                          CUISINES  \
# 0          CASUAL DINING                       Malwani, Goan, North Indian
# 1      CASUAL DINING,BAR                    Asian, Modern Indian, Japanese
# 2          CASUAL DINING        North Indian, Chinese, Biryani, Hyderabadi
# 3            QUICK BITES                                  Tibetan, Chinese
# 4         DESSERT PARLOR                                          Desserts
# ...                  ...                                               ...
# 11367        QUICK BITES                       North Indian, Burger, Kebab
# 11368  CASUAL DINING,BAR                                 Goan, Continental
# 11369             LOUNGE          Finger Food, Continental, Asian, Chinese
# 11370      CASUAL DINING  North Indian, South Indian, Chinese, Street Food
# 11371      CASUAL DINING                             North Indian, Chinese
#
#               CITY              LOCALITY RATING       VOTES  COST
# ...

# %%
df
# Out:
#                    TITLE                                          CUISINES  \
# 0          CASUAL DINING                       Malwani, Goan, North Indian
# 1      CASUAL DINING,BAR                    Asian, Modern Indian, Japanese
# 2          CASUAL DINING        North Indian, Chinese, Biryani, Hyderabadi
# 3            QUICK BITES                                  Tibetan, Chinese
# 4         DESSERT PARLOR                                          Desserts
# ...                  ...                                               ...
# 11367        QUICK BITES                       North Indian, Burger, Kebab
# 11368  CASUAL DINING,BAR                                 Goan, Continental
# 11369             LOUNGE          Finger Food, Continental, Asian, Chinese
# 11370      CASUAL DINING  North Indian, South Indian, Chinese, Street Food
# 11371      CASUAL DINING                             North Indian, Chinese
#
#               CITY              LOCALITY RATING       VOTES  COST
# ...

# %%
print(df['RATING'].unique())
# Out:
# ['3.6' '4.2' '3.8' '4.1' '4.0' '4.3' '3.9' '3.3' '3.4' '4.5' '3.5' '4.4'
#  '2.7' '3.7' '4.7' '3.1' '2.5' '4.6' '2.8' '3.0' '3.2' '2.6' '2.9' '4.9'
#  '4.8' '2.4' '2.3' '2.0' '2.1' '2.2']

# %%
df['VOTES'] = df['VOTES'].str.replace(' votes', '').astype(float)
df
# Out:
#                    TITLE                                          CUISINES  \
# 0          CASUAL DINING                       Malwani, Goan, North Indian
# 1      CASUAL DINING,BAR                    Asian, Modern Indian, Japanese
# 2          CASUAL DINING        North Indian, Chinese, Biryani, Hyderabadi
# 3            QUICK BITES                                  Tibetan, Chinese
# 4         DESSERT PARLOR                                          Desserts
# ...                  ...                                               ...
# 11367        QUICK BITES                       North Indian, Burger, Kebab
# 11368  CASUAL DINING,BAR                                 Goan, Continental
# 11369             LOUNGE          Finger Food, Continental, Asian, Chinese
# 11370      CASUAL DINING  North Indian, South Indian, Chinese, Street Food
# 11371      CASUAL DINING                             North Indian, Chinese
#
#               CITY              LOCALITY RATING   VOTES  COST
# ...

# %%
print(df['TITLE'].unique())                 
print(df['CUISINES'].unique())                       
print(df['CITY'].unique())                  
print(df['LOCALITY'].unique())    
print(df['RATING'].unique())         
print(df['VOTES'].unique())         
print(df['COST'].unique())
# Out:
# ['CASUAL DINING' 'CASUAL DINING,BAR' 'QUICK BITES' 'DESSERT PARLOR' 'CAFÉ'
#  'MICROBREWERY' 'QUICK BITES,BEVERAGE SHOP' 'CASUAL DINING,IRANI CAFE'
#  'BAKERY,QUICK BITES' 'None' 'BAR,CASUAL DINING' 'BAR' 'PUB'
#  'BEVERAGE SHOP' 'FINE DINING' 'CAFÉ,QUICK BITES'
#  'BEVERAGE SHOP,DESSERT PARLOR' 'SWEET SHOP,QUICK BITES'
#  'DESSERT PARLOR,SWEET SHOP' 'BAKERY' 'BAKERY,DESSERT PARLOR' 'BAR,LOUNGE'
#  'FOOD COURT' 'LOUNGE' 'DESSERT PARLOR,BEVERAGE SHOP'
#  'LOUNGE,CASUAL DINING' 'QUICK BITES,FOOD COURT' 'SWEET SHOP'
#  'PUB,CASUAL DINING' 'MESS' 'MICROBREWERY,CASUAL DINING'
#  'CASUAL DINING,SWEET SHOP' 'KIOSK' 'QUICK BITES,KIOSK' 'CLUB'
#  'FINE DINING,BAR' 'DESSERT PARLOR,QUICK BITES' 'FOOD COURT,QUICK BITES'
#  'LOUNGE,CAFÉ' 'BAKERY,CONFECTIONERY' 'DHABA' 'CAFÉ,DESSERT PARLOR'
#  'CASUAL DINING,CAFÉ' 'QUICK BITES,DESSERT PARLOR' 'PUB,MICROBREWERY'
#  'LOUNGE,BAR' 'DESSERT PARLOR,CAFÉ' 'CAFÉ,BAR' 'SWEET SHOP,CONFECTIONERY'
# ...

# %%
from sklearn.preprocessing import LabelEncoder          
lb=LabelEncoder()
df['TITLE']=pd.DataFrame(lb.fit_transform(df['TITLE'])) 
df['CUISINES']=pd.DataFrame(lb.fit_transform(df['CUISINES']))
df['CITY']=pd.DataFrame(lb.fit_transform(df['CITY']))
df['LOCALITY']=pd.DataFrame(lb.fit_transform(df['LOCALITY']))
df
# Out:
#        TITLE  CUISINES  CITY  LOCALITY RATING   VOTES  COST
# 0         29      2463   300       267    3.6    49.0  1200
# 1         31       275    63       961    4.2    30.0  1500
# 2         29      2800    63      1015    3.8   221.0   800
# 3         93      3893   206       128    4.1    24.0   800
# 4         48      1663   206       573    3.8   165.0   300
# ...      ...       ...   ...       ...    ...     ...   ...
# 11367     93      2758   125       318    3.8   546.0   500
# 11368     31      2017   206       125    4.3  1214.0  1800
# 11369     69      1963   223      1241    4.0   608.0  1300
# 11370     29      3305    63       584    3.5    32.0   400
# 11371     29      2770   125      1232    3.4   677.0   600
#
# [11372 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11372 entries, 0 to 11371
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TITLE     11372 non-null  int32
#  1   CUISINES  11372 non-null  int32
#  2   CITY      11372 non-null  int32
#  3   LOCALITY  11372 non-null  int32
#  4   RATING    11372 non-null  object
#  5   VOTES     11372 non-null  float64
#  6   COST      11372 non-null  int64
# dtypes: float64(1), int32(4), int64(1), object(1)
# memory usage: 444.3+ KB

# %%
df['RATING'] = df['RATING'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11372 entries, 0 to 11371
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TITLE     11372 non-null  int32
#  1   CUISINES  11372 non-null  int32
#  2   CITY      11372 non-null  int32
#  3   LOCALITY  11372 non-null  int32
#  4   RATING    11372 non-null  float64
#  5   VOTES     11372 non-null  float64
#  6   COST      11372 non-null  int64
# dtypes: float64(2), int32(4), int64(1)
# memory usage: 444.3 KB

# %% [markdown]
# # Splitting Data into Target and Input Variables

# %%
df_x=df.drop('COST',axis=1)
df_x.head()
# Out:
#    TITLE  CUISINES  CITY  LOCALITY  RATING  VOTES
# 0     29      2463   300       267     3.6   49.0
# 1     31       275    63       961     4.2   30.0
# 2     29      2800    63      1015     3.8  221.0
# 3     93      3893   206       128     4.1   24.0
# 4     48      1663   206       573     3.8  165.0

# %%
y=pd.DataFrame(df.COST)
y.head()
# Out:
#    COST
# 0  1200
# 1  1500
# 2   800
# 3   800
# 4   300

# %%
print(df_x.shape)
print(y.shape)
# Out:
# (11372, 6)
# (11372, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(df_x)                                # Standard Scaling input variables
x = pd.DataFrame(x,columns=df_x.columns) 
x
# Out:
#           TITLE  CUISINES      CITY  LOCALITY    RATING     VOTES
# 0     -0.865373  0.313664  2.119763 -0.920472 -0.436111 -0.434894
# 1     -0.803426 -1.609815 -0.868373  0.967790  0.985411 -0.457350
# 2     -0.865373  0.609922 -0.868373  1.114715  0.037730 -0.231602
# 3      1.116937  1.570783  0.934596 -1.298668  0.748491 -0.464442
# 4     -0.276875 -0.389619  0.934596 -0.087895  0.037730 -0.297790
# ...         ...       ...       ...       ...       ...       ...
# 11367  1.116937  0.573000 -0.086666 -0.781709  0.037730  0.152524
# 11368 -0.803426 -0.078416  0.934596 -1.306830  1.222331  0.942050
# 11369  0.373571 -0.125887  1.148934  1.729624  0.511570  0.225803
# 11370 -0.865373  1.053870 -0.868373 -0.057966 -0.673031 -0.454986
# 11371 -0.865373  0.583549 -0.086666  1.705136 -0.909952  0.307356
#
# [11372 rows x 6 columns]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(x,y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)   
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state,"is",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state,"is",max_r_score)
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()                                   #Applying Linear Regression
r_state=maxr2_score(lreg,x,y)
# Out:
# r2 score corresponding to  42 is 0.14901662985153186
# r2 score corresponding to  43 is 0.17858759558703297
# r2 score corresponding to  44 is 0.14193741776948565
# r2 score corresponding to  45 is 0.18099947981662745
# r2 score corresponding to  46 is 0.17603244905872517
# r2 score corresponding to  47 is 0.14416423238494958
# r2 score corresponding to  48 is 0.1636028035464111
# r2 score corresponding to  49 is 0.14592345261600803
# r2 score corresponding to  50 is 0.16927662173321867
# r2 score corresponding to  51 is 0.18580395758338464
# r2 score corresponding to  52 is 0.16640946688307368
# r2 score corresponding to  53 is 0.1597936770970717
# r2 score corresponding to  54 is 0.17004939091712756
# r2 score corresponding to  55 is 0.16636608273889042
# r2 score corresponding to  56 is 0.13213677162376103
# r2 score corresponding to  57 is 0.17214557511404605
# r2 score corresponding to  58 is 0.1415091028177956
# r2 score corresponding to  59 is 0.15267383902071208
# ...

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBRegressor

# %%
xgbr=XGBRegressor()                                                  # Applying XGBoostRegressor
r_state=maxr2_score(xgbr,x,y)
# Out:
# r2 score corresponding to  42 is 0.7507454950596792
# r2 score corresponding to  43 is 0.7295902770215867
# r2 score corresponding to  44 is 0.6411484911287754
# r2 score corresponding to  45 is 0.7217126626826511
# r2 score corresponding to  46 is 0.7026860467242508
# r2 score corresponding to  47 is 0.6965846091540311
# r2 score corresponding to  48 is 0.6871859521956774
# r2 score corresponding to  49 is 0.6617988538230011
# r2 score corresponding to  50 is 0.7116796629097238
# r2 score corresponding to  51 is 0.7290584651790508
# r2 score corresponding to  52 is 0.6962420712374137
# r2 score corresponding to  53 is 0.6906301457681017
# r2 score corresponding to  54 is 0.7380840539324971
# r2 score corresponding to  55 is 0.7440590512685379
# r2 score corresponding to  56 is 0.6556404446867172
# r2 score corresponding to  57 is 0.7335016095609139
# r2 score corresponding to  58 is 0.6838331225077096
# r2 score corresponding to  59 is 0.6519909405875931
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor              #Applying KNeighborsRegressor
knr=KNeighborsRegressor(n_neighbors=3) 
r_state=maxr2_score(knr,x,y)
# Out:
# r2 score corresponding to  42 is 0.39521619348601866
# r2 score corresponding to  43 is 0.4548755433183679
# r2 score corresponding to  44 is 0.2989880444755546
# r2 score corresponding to  45 is 0.3281280169674724
# r2 score corresponding to  46 is 0.36387442473976594
# r2 score corresponding to  47 is 0.3575698379232598
# r2 score corresponding to  48 is 0.36484091081745007
# r2 score corresponding to  49 is 0.3389361143064392
# r2 score corresponding to  50 is 0.39601119789763173
# r2 score corresponding to  51 is 0.4091499498116613
# r2 score corresponding to  52 is 0.3646564944002144
# r2 score corresponding to  53 is 0.3635042273990008
# r2 score corresponding to  54 is 0.41866463600451853
# r2 score corresponding to  55 is 0.41832623238627287
# r2 score corresponding to  56 is 0.2906817689937494
# r2 score corresponding to  57 is 0.38457072556175476
# r2 score corresponding to  58 is 0.33868703205361506
# r2 score corresponding to  59 is 0.3218598473904327
# ...

# %%
from sklearn.linear_model import Lasso         # Applying Lasso Regression
lsreg=Lasso(alpha=0.01)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2 score corresponding to  42 is 0.14902029980260445
# r2 score corresponding to  43 is 0.17858663190413326
# r2 score corresponding to  44 is 0.14193768896314296
# r2 score corresponding to  45 is 0.18100066123198766
# r2 score corresponding to  46 is 0.17603357978674894
# r2 score corresponding to  47 is 0.14417206626053813
# r2 score corresponding to  48 is 0.1636024075008201
# r2 score corresponding to  49 is 0.14592394892653648
# r2 score corresponding to  50 is 0.16927693398095411
# r2 score corresponding to  51 is 0.1858033566641647
# r2 score corresponding to  52 is 0.1664168620821873
# r2 score corresponding to  53 is 0.1597937807081169
# r2 score corresponding to  54 is 0.1700488915592906
# r2 score corresponding to  55 is 0.16637427589859843
# r2 score corresponding to  56 is 0.1321410849481044
# r2 score corresponding to  57 is 0.17214667922730809
# r2 score corresponding to  58 is 0.14151279926659288
# r2 score corresponding to  59 is 0.15267310439095694
# ...

# %%
# Prediction of Training Dataset with the best working Model XGBRegressor which is having accuracy score 0.7661958437451071

x_train, x_test, y_train, y_test = train_test_split(x,y,random_state = 81,test_size=0.20)
xgbr.fit(x_train,y_train)
y_pred = xgbr.predict(x_test)  
r2_scr=r2_score(y_test,y_pred) 
print(r2_scr)
print(y_pred)
# Out:
# 0.7661958437451071
# [ 329.17947 2349.6794  1287.0603  ... 1224.544    429.34866  456.00284]

# %%
# saving the Model with XGBoostRegressor
from sklearn.externals import joblib
joblib.dump(xgbr, 'XGBoostRegressor_Restaurant_Food_Cost.pkl')
# Out:
# ['XGBoostRegressor_Restaurant_Food_Cost.pkl']

# %% [markdown]
# # Working with Test Dataset for prediction

# %%
df1 = pd.read_excel(r'C:\Users\Hi\Desktop\Data_Test.xlsx')
df1
# Out:
#               TITLE  RESTAURANT_ID  \
# 0     CASUAL DINING           4085
# 1       QUICK BITES          12680
# 2     CASUAL DINING           1411
# 3              None            204
# 4       QUICK BITES          13453
# ...             ...            ...
# 4226  CASUAL DINING           9057
# 4227           None           1247
# 4228    QUICK BITES           8617
# 4229    QUICK BITES           6485
# 4230    QUICK BITES           2421
#
#                                            CUISINES  \
# 0             North Indian, Chinese, Mughlai, Kebab
# 1      South Indian, Fast Food, Pizza, North Indian
# 2           North Indian, Seafood, Biryani, Chinese
# 3                                           Biryani
# 4                              South Indian, Kerala
# ...                                             ...
# 4226                 North Indian, Mughlai, Chinese
# 4227  Biryani, North Indian, Sandwich, Salad, Wraps
# 4228                      Continental, North Indian
# ...

# %%
df1.isna().sum()
# Out:
# TITLE              0
# RESTAURANT_ID      0
# CUISINES           0
# TIME               0
# CITY              35
# LOCALITY          30
# RATING             2
# VOTES            402
# dtype: int64

# %%
df1=df1.dropna(subset = ['CITY']) 
df1=df1.dropna(subset = ['LOCALITY']) 
df1=df1.dropna(subset = ['RATING']) 
df1=df1.dropna(subset = ['VOTES']) 
df1 = df1.reset_index(drop=True)
df1
# Out:
#               TITLE  RESTAURANT_ID  \
# 0     CASUAL DINING           4085
# 1       QUICK BITES          12680
# 2     CASUAL DINING           1411
# 3              None            204
# 4       QUICK BITES          13453
# ...             ...            ...
# 3792    QUICK BITES           1670
# 3793  CASUAL DINING           9057
# 3794           None           1247
# 3795    QUICK BITES           8617
# 3796    QUICK BITES           2421
#
#                                            CUISINES  \
# 0             North Indian, Chinese, Mughlai, Kebab
# 1      South Indian, Fast Food, Pizza, North Indian
# 2           North Indian, Seafood, Biryani, Chinese
# 3                                           Biryani
# 4                              South Indian, Kerala
# ...                                             ...
# 3792                 North Indian, Mughlai, Chinese
# 3793                 North Indian, Mughlai, Chinese
# 3794  Biryani, North Indian, Sandwich, Salad, Wraps
# ...

# %%
df1.isna().sum()
# Out:
# TITLE            0
# RESTAURANT_ID    0
# CUISINES         0
# TIME             0
# CITY             0
# LOCALITY         0
# RATING           0
# VOTES            0
# dtype: int64

# %%
df1=df1.drop(['RESTAURANT_ID','TIME'],axis=1)  
df1
# Out:
#               TITLE                                       CUISINES  \
# 0     CASUAL DINING          North Indian, Chinese, Mughlai, Kebab
# 1       QUICK BITES   South Indian, Fast Food, Pizza, North Indian
# 2     CASUAL DINING        North Indian, Seafood, Biryani, Chinese
# 3              None                                        Biryani
# 4       QUICK BITES                           South Indian, Kerala
# ...             ...                                            ...
# 3792    QUICK BITES                 North Indian, Mughlai, Chinese
# 3793  CASUAL DINING                 North Indian, Mughlai, Chinese
# 3794           None  Biryani, North Indian, Sandwich, Salad, Wraps
# 3795    QUICK BITES                      Continental, North Indian
# 3796    QUICK BITES                                        Mughlai
#
#              CITY          LOCALITY RATING       VOTES
# 0           Noida         Sector 18    4.3   564 votes
# ...

# %%
print(df1['TITLE'].unique())                 
print(df1['CUISINES'].unique())                       
print(df1['CITY'].unique())                  
print(df1['LOCALITY'].unique())    
print(df1['RATING'].unique())         
print(df1['VOTES'].unique())
# Out:
# ['CASUAL DINING' 'QUICK BITES' 'None' 'FOOD TRUCK,DESSERT PARLOR'
#  'DESSERT PARLOR,QUICK BITES' 'CASUAL DINING,BAR' 'LOUNGE' 'BEVERAGE SHOP'
#  'CASUAL DINING,PUB' 'DESSERT PARLOR' 'PUB' 'CAFÉ' 'BAKERY' 'LOUNGE,BAR'
#  'BAKERY,QUICK BITES' 'SWEET SHOP' 'SWEET SHOP,QUICK BITES'
#  'BEVERAGE SHOP,QUICK BITES' 'CAFÉ,QUICK BITES' 'DHABA'
#  'QUICK BITES,DESSERT PARLOR' 'FINE DINING' 'IRANI CAFE,BAKERY'
#  'PUB,CASUAL DINING' 'BAR' 'FOOD COURT' 'QUICK BITES,SWEET SHOP'
#  'CAFÉ,BAR' 'BAR,PUB' 'BAKERY,DESSERT PARLOR' 'KIOSK' 'CAFÉ,BAKERY'
#  'CASUAL DINING,BAKERY' 'BAKERY,CAFÉ' 'CASUAL DINING,CAFÉ' 'MESS'
#  'BAR,CASUAL DINING' 'BEVERAGE SHOP,CAFÉ' 'BEVERAGE SHOP,DESSERT PARLOR'
#  'PUB,FINE DINING' 'CASUAL DINING,FOOD COURT' 'CAFÉ,CASUAL DINING'
#  'LOUNGE,CASUAL DINING' 'DESSERT PARLOR,CAFÉ' 'FINE DINING,BAR'
#  'CASUAL DINING,SWEET SHOP' 'LOUNGE,FINE DINING' 'MICROBREWERY,PUB'
#  'FOOD TRUCK' 'CASUAL DINING,MICROBREWERY' 'CLUB' 'CAFÉ,FOOD COURT'
# ...

# %%
df1=df1.drop_duplicates()

df1
# Out:
#               TITLE                                       CUISINES  \
# 0     CASUAL DINING          North Indian, Chinese, Mughlai, Kebab
# 1       QUICK BITES   South Indian, Fast Food, Pizza, North Indian
# 2     CASUAL DINING        North Indian, Seafood, Biryani, Chinese
# 3              None                                        Biryani
# 4       QUICK BITES                           South Indian, Kerala
# ...             ...                                            ...
# 3792    QUICK BITES                 North Indian, Mughlai, Chinese
# 3793  CASUAL DINING                 North Indian, Mughlai, Chinese
# 3794           None  Biryani, North Indian, Sandwich, Salad, Wraps
# 3795    QUICK BITES                      Continental, North Indian
# 3796    QUICK BITES                                        Mughlai
#
#              CITY          LOCALITY RATING       VOTES
# 0           Noida         Sector 18    4.3   564 votes
# ...

# %%
df1 = df1.reset_index(drop=True)
df1
# Out:
#               TITLE                                       CUISINES  \
# 0     CASUAL DINING          North Indian, Chinese, Mughlai, Kebab
# 1       QUICK BITES   South Indian, Fast Food, Pizza, North Indian
# 2     CASUAL DINING        North Indian, Seafood, Biryani, Chinese
# 3              None                                        Biryani
# 4       QUICK BITES                           South Indian, Kerala
# ...             ...                                            ...
# 3791    QUICK BITES                 North Indian, Mughlai, Chinese
# 3792  CASUAL DINING                 North Indian, Mughlai, Chinese
# 3793           None  Biryani, North Indian, Sandwich, Salad, Wraps
# 3794    QUICK BITES                      Continental, North Indian
# 3795    QUICK BITES                                        Mughlai
#
#              CITY          LOCALITY RATING       VOTES
# 0           Noida         Sector 18    4.3   564 votes
# ...

# %%
df1['VOTES'] = df1['VOTES'].str.replace(' votes', '').astype(float)
df1
# Out:
#               TITLE                                       CUISINES  \
# 0     CASUAL DINING          North Indian, Chinese, Mughlai, Kebab
# 1       QUICK BITES   South Indian, Fast Food, Pizza, North Indian
# 2     CASUAL DINING        North Indian, Seafood, Biryani, Chinese
# 3              None                                        Biryani
# 4       QUICK BITES                           South Indian, Kerala
# ...             ...                                            ...
# 3791    QUICK BITES                 North Indian, Mughlai, Chinese
# 3792  CASUAL DINING                 North Indian, Mughlai, Chinese
# 3793           None  Biryani, North Indian, Sandwich, Salad, Wraps
# 3794    QUICK BITES                      Continental, North Indian
# 3795    QUICK BITES                                        Mughlai
#
#              CITY          LOCALITY RATING   VOTES
# 0           Noida         Sector 18    4.3   564.0
# 1          Mumbai        Grant Road    4.2    61.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3796 entries, 0 to 3795
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TITLE     3796 non-null   object
#  1   CUISINES  3796 non-null   object
#  2   CITY      3796 non-null   object
#  3   LOCALITY  3796 non-null   object
#  4   RATING    3796 non-null   object
#  5   VOTES     3796 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 178.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder          
lb=LabelEncoder()
df1['TITLE']=pd.DataFrame(lb.fit_transform(df1['TITLE'])) 
df1['CUISINES']=pd.DataFrame(lb.fit_transform(df1['CUISINES']))
df1['CITY']=pd.DataFrame(lb.fit_transform(df1['CITY']))
df1['LOCALITY']=pd.DataFrame(lb.fit_transform(df1['LOCALITY']))
df1
# Out:
#       TITLE  CUISINES  CITY  LOCALITY RATING   VOTES
# 0        22      1210   103       619    4.3   564.0
# 1        73      1528    90       208    4.2    61.0
# 2        22      1368    90       388    3.8   350.0
# 3        64       190    41       433    3.8  1445.0
# 4        73      1532    74       283    3.6    23.0
# ...     ...       ...   ...       ...    ...     ...
# 3791     73      1339    90       208    4.0   197.0
# 3792     22      1339   101       557    3.9   287.0
# 3793     64       246     9       224    4.3   469.0
# 3794     73       635    41       651    3.7    53.0
# 3795     73      1071     8       542    3.7    63.0
#
# [3796 rows x 6 columns]

# %%
df1['RATING'] = df1['RATING'].astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3796 entries, 0 to 3795
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TITLE     3796 non-null   int32
#  1   CUISINES  3796 non-null   int32
#  2   CITY      3796 non-null   int32
#  3   LOCALITY  3796 non-null   int32
#  4   RATING    3796 non-null   float64
#  5   VOTES     3796 non-null   float64
# dtypes: float64(2), int32(4)
# memory usage: 118.8 KB

# %%
print(df1.shape)
# Out:
# (3796, 6)

# %%
df_x1=df1           # putting test_x data into another variable
df_x1
# Out:
#       TITLE  CUISINES  CITY  LOCALITY  RATING   VOTES
# 0        22      1210   103       619     4.3   564.0
# 1        73      1528    90       208     4.2    61.0
# 2        22      1368    90       388     3.8   350.0
# 3        64       190    41       433     3.8  1445.0
# 4        73      1532    74       283     3.6    23.0
# ...     ...       ...   ...       ...     ...     ...
# 3791     73      1339    90       208     4.0   197.0
# 3792     22      1339   101       557     3.9   287.0
# 3793     64       246     9       224     4.3   469.0
# 3794     73       635    41       651     3.7    53.0
# 3795     73      1071     8       542     3.7    63.0
#
# [3796 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler          # Standard scaling input variables
sc = StandardScaler()
x1 = sc.fit_transform(df_x1) 
x1 = pd.DataFrame(x1,columns=df_x1.columns) 
x1
# Out:
#          TITLE  CUISINES      CITY  LOCALITY    RATING     VOTES
# 0    -0.839927  0.718567  1.327734  1.181529  1.200058  0.159141
# 1     1.138207  1.396547  0.969163 -0.685600  0.969030 -0.443761
# 2    -0.839927  1.055425  0.969163  0.132121  0.044915 -0.097362
# 3     0.789124 -1.456084 -0.382375  0.336551  0.044915  1.215118
# 4     1.138207  1.405075  0.527844 -0.344883 -0.417142 -0.489308
# ...        ...       ...       ...       ...       ...       ...
# 3791  1.138207  0.993596  0.969163 -0.685600  0.506973 -0.280750
# 3792 -0.839927  0.993596  1.272569  0.899870  0.275944 -0.172875
# 3793  0.789124 -1.336692 -1.265012 -0.612913  1.200058  0.045273
# 3794  1.138207 -0.507339 -0.382375  1.326902 -0.186113 -0.453350
# 3795  1.138207  0.422217 -1.292595  0.831726 -0.186113 -0.441364
#
# [3796 rows x 6 columns]

# %%
test_dataset_x=x1                #s test_dataset_x is for prediction
test_dataset_x
# Out:
#          TITLE  CUISINES      CITY  LOCALITY    RATING     VOTES
# 0    -0.839927  0.718567  1.327734  1.181529  1.200058  0.159141
# 1     1.138207  1.396547  0.969163 -0.685600  0.969030 -0.443761
# 2    -0.839927  1.055425  0.969163  0.132121  0.044915 -0.097362
# 3     0.789124 -1.456084 -0.382375  0.336551  0.044915  1.215118
# 4     1.138207  1.405075  0.527844 -0.344883 -0.417142 -0.489308
# ...        ...       ...       ...       ...       ...       ...
# 3791  1.138207  0.993596  0.969163 -0.685600  0.506973 -0.280750
# 3792 -0.839927  0.993596  1.272569  0.899870  0.275944 -0.172875
# 3793  0.789124 -1.336692 -1.265012 -0.612913  1.200058  0.045273
# 3794  1.138207 -0.507339 -0.382375  1.326902 -0.186113 -0.453350
# 3795  1.138207  0.422217 -1.292595  0.831726 -0.186113 -0.441364
#
# [3796 rows x 6 columns]

# %%
# Prediction of Test Dataset with the best working Model XGBRegressor which is having accuracy score 0.7661958437451071

y_pred2 = xgbr.predict(test_dataset_x)  
print(y_pred2)
# Out:
# [ 941.76996  391.10583  631.27    ... 1384.2555   363.721    484.91055]
